# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
# load iris data
from sklearn import datasets

iris = datasets.load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %% [markdown]
# ## Scatter plots
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

# %%
data = pd.DataFrame(data= iris.data, columns=iris.feature_names)
names= {0:'setosa',1:'versicolor', 2:'virginica'}
data['species']=pd.Series(iris.target).map(names)

# %%
data.head(1)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
#
#   species
# 0  setosa

# %%
import matplotlib.pyplot as plt

classes, ax = plt.subplots()
scatter = ax.scatter(iris.data[:, 0], iris.data[:, 1], c=iris.target)
ax.set(xlabel=iris.feature_names[0], ylabel=iris.feature_names[1])

classes= ax.legend(
    scatter.legend_elements()[0], iris.target_names, title="Classes")

# %%
import  seaborn as sn

# %%
sn.pairplot(data, hue='species')

# %%
from  sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test= train_test_split(iris.data, iris.target, train_size=0.9)
# standard scaler is a normalization technique
std = StandardScaler()
X_train_std = std.fit_transform(X_train)
X_test_std= std.fit_transform((X_test))

# %% [markdown]
# ## KNN
# - https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
from sklearn.neighbors import KNeighborsClassifier

knn= KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_std,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
print(f'Training Score: {knn.score(X_train_std,y_train)}')
# Out:
# Training Score: 0.9481481481481482

# %%
print(f'Test Score: {knn.score(X_test_std,y_test)}')
# Out:
# Test Score: 0.9333333333333333

# %% [markdown]
# + when we decrese the k we get more score but when we increase the k we get less score
